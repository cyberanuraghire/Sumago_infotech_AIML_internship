# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Solution 1: Use double backslashes
df = pd.read_csv("Desktop\\machine learing\\titanic.csv")

# Solution 2: Use a raw string (prefix with r)
#df = pd.read_csv(r"Desktop\machine learing\titanic.csv")

# Solution 3: Use forward slashes (works in Windows)
#df = pd.read_csv("Desktop/machine learing/titanic.csv")

# Display the first few rows
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop(columns=['Cabin', 'Embarked'], inplace=True)

# %%
avg_age = df.Age.mean()
df.Age.replace(np.nan, avg_age, inplace = True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare
# 0      0         A/5 21171   7.2500
# 1      0          PC 17599  71.2833
# 2      0  STON/O2. 3101282   7.9250
# 3      0            113803  53.1000
# 4      0            373450   8.0500

# %%
dummies = pd.get_dummies(df.Sex, dtype=int)
dummies
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]

# %%
merged = pd.concat([df,dummies], axis='columns')
merged
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
final = merged.drop(['Name','Sex','Parch','Ticket','PassengerId','SibSp'], axis='columns')
final
# Out:
#      Survived  Pclass        Age     Fare  female  male
# 0           0       3  22.000000   7.2500       0     1
# 1           1       1  38.000000  71.2833       1     0
# 2           1       3  26.000000   7.9250       1     0
# 3           1       1  35.000000  53.1000       1     0
# 4           0       3  35.000000   8.0500       0     1
# ..        ...     ...        ...      ...     ...   ...
# 886         0       2  27.000000  13.0000       0     1
# 887         1       1  19.000000  30.0000       1     0
# 888         0       3  29.699118  23.4500       1     0
# 889         1       1  26.000000  30.0000       0     1
# 890         0       3  32.000000   7.7500       0     1
#
# [891 rows x 6 columns]

# %%
input = final.drop('Survived', axis='columns')
input
# Out:
#      Pclass        Age     Fare  female  male
# 0         3  22.000000   7.2500       0     1
# 1         1  38.000000  71.2833       1     0
# 2         3  26.000000   7.9250       1     0
# 3         1  35.000000  53.1000       1     0
# 4         3  35.000000   8.0500       0     1
# ..      ...        ...      ...     ...   ...
# 886       2  27.000000  13.0000       0     1
# 887       1  19.000000  30.0000       1     0
# 888       3  29.699118  23.4500       1     0
# 889       1  26.000000  30.0000       0     1
# 890       3  32.000000   7.7500       0     1
#
# [891 rows x 5 columns]

# %%
target = final.Survived
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
model.fit(input, target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(input,target)
# Out:
# 0.9797979797979798

# %%
model.predict([[1,38,71,1,0]])
# Out:
# array([1], dtype=int64)

# %%
#now model after scallin ghe data
final
# Out:
#      Survived  Pclass        Age     Fare  female  male
# 0           0       3  22.000000   7.2500       0     1
# 1           1       1  38.000000  71.2833       1     0
# 2           1       3  26.000000   7.9250       1     0
# 3           1       1  35.000000  53.1000       1     0
# 4           0       3  35.000000   8.0500       0     1
# ..        ...     ...        ...      ...     ...   ...
# 886         0       2  27.000000  13.0000       0     1
# 887         1       1  19.000000  30.0000       1     0
# 888         0       3  29.699118  23.4500       1     0
# 889         1       1  26.000000  30.0000       0     1
# 890         0       3  32.000000   7.7500       0     1
#
# [891 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
final[['Age','Fare']] = scaler.fit_transform(final[['Age','Fare']])

# %%
final
# Out:
#      Survived  Pclass       Age      Fare  female  male
# 0           0       3 -0.592481 -0.502445       0     1
# 1           1       1  0.638789  0.786845       1     0
# 2           1       3 -0.284663 -0.488854       1     0
# 3           1       1  0.407926  0.420730       1     0
# 4           0       3  0.407926 -0.486337       0     1
# ..        ...     ...       ...       ...     ...   ...
# 886         0       2 -0.207709 -0.386671       0     1
# 887         1       1 -0.823344 -0.044381       1     0
# 888         0       3  0.000000 -0.176263       1     0
# 889         1       1 -0.284663 -0.044381       0     1
# 890         0       3  0.177063 -0.492378       0     1
#
# [891 rows x 6 columns]

# %%
x = input = final.drop('Survived', axis='columns')
x
# Out:
#      Pclass       Age      Fare  female  male
# 0         3 -0.592481 -0.502445       0     1
# 1         1  0.638789  0.786845       1     0
# 2         3 -0.284663 -0.488854       1     0
# 3         1  0.407926  0.420730       1     0
# 4         3  0.407926 -0.486337       0     1
# ..      ...       ...       ...     ...   ...
# 886       2 -0.207709 -0.386671       0     1
# 887       1 -0.823344 -0.044381       1     0
# 888       3  0.000000 -0.176263       1     0
# 889       1 -0.284663 -0.044381       0     1
# 890       3  0.177063 -0.492378       0     1
#
# [891 rows x 5 columns]

# %%
y = final.Survived
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.6)

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
model.fit(x, y)
# Out:
# DecisionTreeClassifier()

# %%
model.score(x,y)
# Out:
# 0.9797979797979798
